# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Downloads/covid_count_per_zip_all.csv")
df2 = pd.read_csv("Downloads/IndianaCounties.csv")

# %%
df
# Out:
#      ZIP_CD PATIENT_COUNT  POPULATION  PERCENTAGE
# 0     46502    Suppressed  Suppressed  Suppressed
# 1     46771    Suppressed  Suppressed  Suppressed
# 2     46922    Suppressed  Suppressed  Suppressed
# 3     46968    Suppressed  Suppressed  Suppressed
# 4     46998    Suppressed  Suppressed  Suppressed
# ..      ...           ...         ...         ...
# 766   46140          2306       38543    5.982900
# 767   46142          2051       30413    6.743800
# 768   46151          1814       30921    5.866500
# 769   46203          2018       38950    5.181000
# 770   46219          1862       33930    5.487700
#
# [771 rows x 4 columns]

# %%
df2
# Out:
#         Unnamed: 0 Unnamed: 1                  Unnamed: 2              S001  \
# 0              NaN        NaN                         NaN       SEX AND AGE
# 1              NaN        NaN                         NaN  Total population
# 2              NaN        NaN                         NaN               NaN
# 3              NaN        NaN                         NaN               NaN
# 4              NaN        NaN                         NaN               NaN
# ..             ...        ...                         ...               ...
# 95  0500000US18175      18175  Washington County, Indiana             28262
# 96  0500000US18177      18177       Wayne County, Indiana             68917
# 97  0500000US18179      18179       Wells County, Indiana             27636
# 98  0500000US18181      18181       White County, Indiana             24643
# 99  0500000US18183      18183     Whitley County, Indiana             33292
#
# ...
